# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpy1 = np.linspace(0,10,20)
numpy1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpy2 = numpy1 ** 2
numpy2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigure,benimEksen) = plt.subplots()
benimEksen.plot(numpy1,numpy2,color="#1526",alpha = 0.7)
benimEksen.plot(numpy2,numpy1,color="#7532",alpha = 0.7);

# %%
(yeniFigur,yeniEksen) = plt.subplots()
yeniEksen.plot(numpy1,numpy1 + 2,"b",linewidth = 5)
yeniEksen.plot(numpy1,numpy1 + 3,"y",linewidth = 3)

yeniEksen.plot(numpy1,numpy1 + 4,"r",linestyle = "-.")
yeniEksen.plot(numpy1,numpy1 + 1,"c",linestyle = "--")

yeniEksen.plot(numpy1,numpy1 + 5,"black",linestyle = "--",marker = "o",markersize = 8,markerfacecolor="red")

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpy1,numpy2)

# %% [markdown]
# ## histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([92, 43, 75, 88, 59, 58, 93, 45, 32, 56, 99,  4, 64, 27, 95, 16, 32,
#         7, 58, 28, 29, 64,  5, 98, 72, 44, 90, 93, 57, 24,  2, 82, 92, 35,
#        87, 68, 20, 68, 28, 13,  5, 37, 50, 79, 15, 62, 54, 63, 35, 93])

# %%
plt.hist(yeniDizi,color="y")
# Out:
# (array([5., 4., 5., 5., 4., 6., 6., 3., 3., 9.]),
#  array([ 2. , 11.7, 21.4, 31.1, 40.8, 50.5, 60.2, 69.9, 79.6, 89.3, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi*2);
